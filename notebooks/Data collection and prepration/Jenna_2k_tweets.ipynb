# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# create list to append tweet data to
tweets_list = []

# %%
# params
keywords = 'migrant OR migrants OR migrates OR migrated OR migration OR foreigner OR foreigners OR immigration OR immigrants OR immigrant OR asylum OR refugee OR refugees OR visa OR visas OR border OR borders OR deport OR deportation OR deported OR deports'

# %%
# %%time

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(f'{keywords} from:TheSun OR from:DailyMailUK OR from:MailOnline OR from:Daily_Express').get_items()):
    if i>2000:
        break
    tweets_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount])
tweets_list
# Out:
# [[datetime.datetime(2022, 6, 7, 2, 12, tzinfo=datetime.timezone.utc),
#   1533995157858795525,
#   'Biden blasted for ‘monumental disaster’ as 11,000 migrants head to the US-Mexico border \n\nhttps://t.co/QZ5q7ZqAb5 https://t.co/bczXh8v30m',
#   'Daily_Express',
#   3],
#  [datetime.datetime(2022, 6, 6, 11, 40, 5, tzinfo=datetime.timezone.utc),
#   1533775732345823232,
#   'More than 45,000 Americans apply to sponsor Ukrainian refugees in just a month https://t.co/tFO8AFjXaE',
#   'MailOnline',
#   17],
#  [datetime.datetime(2022, 6, 5, 3, 29, 56, tzinfo=datetime.timezone.utc),
#   1533289994584002561,
#   'Anger as hundreds of refugee children from Ukraine are left stranded abroad following Home Office rule change https://t.co/UvMjfLaXzC',
#   'MailOnline',
#   16],
#  [datetime.datetime(2022, 6, 4, 0, 40, 42, tzinfo=datetime.timezone.utc),
#   1532885015918411777,
#   'More than 10,000 migrants have already crossed the Channel this year despite the threat they could be deported to Rwanda https://t.co/sU3JublEXy',
#   'MailOnline',
#   17],
#  [datetime.datetime(2022, 6, 3, 23, 30, 7, tzinfo=datetime.timezone.utc),
#   1532867253988884485,
#   'This week marked one hundred days since Russian tanks rolled across the border and into neighbouring Ukraine https://t.co/BrbVTxsrUh',
#   'MailOnline',
#   16],
#  [datetime.datetime(2022, 6, 3, 10, 43, 47, tzinfo=datetime.timezone.utc),
#   1532674399828119555,
#   "'It can't go on like this' Rwanda policy 'not working' as almost 10,000 migrants reach UK\nhttps://t.co/7G6k4zPGv7",
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 6, 3, 2, 26, tzinfo=datetime.timezone.utc),
#   1532549128198115328,
#   'Biden close to finalising deal to send refugees to Spain amid staggering migrant crisis \n\nhttps://t.co/rasMXPoHaS https://t.co/O4hJY3hoFT',
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 6, 2, 19, 52, 5, tzinfo=datetime.timezone.utc),
#   1532449997849083904,
#   "Russian military forcibly deport over 200,000 Ukrainian children in Putin's takeover plot \nhttps://t.co/Oz8QgopGVI",
#   'Daily_Express',
#   6],
#  [datetime.datetime(2022, 6, 2, 16, 1, 34, tzinfo=datetime.timezone.utc),
#   1532391986921185281,
#   'Russia unleashes hypersonic missile on NATO supply line inside Ukraine in desperate bid to stop arms crossing border\nhttps://t.co/wf4o5T6eEm',
#   'TheSun',
#   12],
#  [datetime.datetime(2022, 6, 2, 12, 58, 4, tzinfo=datetime.timezone.utc),
#   1532345807667617793,
#   'Up to 100 more migrants arrive in Dover after being picked up in the Channel https://t.co/EREeitowD3',
#   'DailyMailUK',
#   6],
#  [datetime.datetime(2022, 6, 2, 3, 58, 54, tzinfo=datetime.timezone.utc),
#   1532210118804312064,
#   'Now even TONY BLAIR says the EU must back down over NI border checks https://t.co/YnNPiwU2XJ',
#   'DailyMailUK',
#   11],
#  [datetime.datetime(2022, 6, 2, 0, 30, 3, tzinfo=datetime.timezone.utc),
#   1532157561239117824,
#   "Boris calls for 'more pragmatism and less theology' from EU in dispute over NI border checks https://t.co/UxNGkBjmEx",
#   'DailyMailUK',
#   5],
#  [datetime.datetime(2022, 6, 1, 15, 10, 5, tzinfo=datetime.timezone.utc),
#   1532016641839611904,
#   'Children clutching teddies are brought ashore at Dover as more than 100 migrants cross the Channel https://t.co/8l5J0LFFgy',
#   'DailyMailUK',
#   8],
#  [datetime.datetime(2022, 6, 1, 14, 10, 6, tzinfo=datetime.timezone.utc),
#   1532001544572387346,
#   "Boris calls for 'more pragmatism and less theology' from EU in dispute over NI border checks https://t.co/Oh1dPz547h",
#   'DailyMailUK',
#   14],
#  [datetime.datetime(2022, 6, 1, 12, 20, 9, tzinfo=datetime.timezone.utc),
#   1531973876669898753,
#   'Now even TONY BLAIR says the EU must back down over NI border checks https://t.co/VhJDg46uce',
#   'DailyMailUK',
#   5],
#  [datetime.datetime(2022, 6, 1, 0, 16, tzinfo=datetime.timezone.utc),
#   1531791637231259648,
#   "GB News: Nigel Farage slams PM over Brexit border control deceit 'They couldn't care less' \n\nhttps://t.co/wRNhztPPcD https://t.co/jkiSLurTYA",
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 6, 1, 0, 15, 9, tzinfo=datetime.timezone.utc),
#   1531791425402290176,
#   'Ukrainian refugee recognises her new boiler photographed on top of a Russian tank in Luhansk https://t.co/5TvL8L8n8u',
#   'MailOnline',
#   29],
#  [datetime.datetime(2022, 5, 31, 23, 35, 24, tzinfo=datetime.timezone.utc),
#   1531781419013443584,
#   "'What wasn't destroyed they stole’ Ukrainian refugee sees looted items on Russian tank https://t.co/KGXATglgwS",
#   'Daily_Express',
#   3],
#  [datetime.datetime(2022, 5, 31, 19, 41, 1, tzinfo=datetime.timezone.utc),
#   1531722436089196545,
#   'Defiant villagers protesting new centre for 1,500 young single male asylum seekers https://t.co/yReDaTQ1tX',
#   'DailyMailUK',
#   24],
#  [datetime.datetime(2022, 5, 31, 19, 0, 11, tzinfo=datetime.timezone.utc),
#   1531712162107883524,
#   "EXCLUSIVE: The £46-a-night hotel in Rwanda that will house UK's illegal migrants https://t.co/F6xCMvmtys",
#   'DailyMailUK',
#   13],
#  [datetime.datetime(2022, 5, 31, 17, 30, 4, tzinfo=datetime.timezone.utc),
#   1531689480759005190,
#   'Home Office tells first migrants they will be sent to Rwanda in TWO WEEKS https://t.co/uS6qmx34p1',
#   'DailyMailUK',
#   37],
#  [datetime.datetime(2022, 5, 31, 12, 4, 18, tzinfo=datetime.timezone.utc),
#   1531607500650323968,
#   "Inside the £46-a-night hotel in Rwanda that will house UK's illegal migrants https://t.co/NTRWLwNT6u https://t.co/GEZ5jiTGOV",
#   'MailOnline',
#   19],
#  [datetime.datetime(2022, 5, 31, 12, 0, 10, tzinfo=datetime.timezone.utc),
#   1531606457648615424,
#   "Inside the £46-a-night hotel in Rwanda that will house UK's illegal migrants https://t.co/n2f9flNoca",
#   'MailOnline',
#   10],
#  [datetime.datetime(2022, 5, 31, 11, 55, 20, tzinfo=datetime.timezone.utc),
#   1531605241539481601,
#   'At least 100 migrants including women and small children arrive in Dover after being picked up in Channel https://t.co/g2V4TYySml',
#   'DailyMailUK',
#   22],
#  [datetime.datetime(2022, 5, 31, 10, 0, 16, tzinfo=datetime.timezone.utc),
#   1531576285213892613,
#   "EXCLUSIVE: The £46-a-night hotel in Rwanda that will house UK's illegal migrants https://t.co/77fdr3SDZA",
#   'DailyMailUK',
#   22],
#  [datetime.datetime(2022, 5, 31, 9, 25, 5, tzinfo=datetime.timezone.utc),
#   1531567432304934913,
#   "Inside the £46-a-night hotel in Rwanda that will house UK's illegal migrants https://t.co/Yt46BRYBbq",
#   'MailOnline',
#   24],
#  [datetime.datetime(2022, 5, 31, 6, 56, 40, tzinfo=datetime.timezone.utc),
#   1531530080782102528,
#   "Defiant villagers protesting new migrant centre told by Home Office 'no final decision has been made' https://t.co/DUT4GrQx1U",
#   'DailyMailUK',
#   22],
#  [datetime.datetime(2022, 5, 31, 0, 31, 4, tzinfo=datetime.timezone.utc),
#   1531433041448550400,
#   "First migrants 'face being handed Rwanda notices THIS WEEK' https://t.co/0Ks5HQ300A",
#   'DailyMailUK',
#   24],
#  [datetime.datetime(2022, 5, 30, 21, 40, 10, tzinfo=datetime.timezone.utc),
#   1531390033176952833,
#   "First migrants 'face being handed Rwanda notices THIS WEEK' https://t.co/TDgwjuDLLh",
#   'MailOnline',
#   35],
#  [datetime.datetime(2022, 5, 30, 16, 10, 5, tzinfo=datetime.timezone.utc),
#   1531306965288222720,
#   "First migrants 'face being handed Rwanda notices THIS WEEK' https://t.co/FZ5cmFrrYR",
#   'MailOnline',
#   33],
#  [datetime.datetime(2022, 5, 30, 15, 40, 8, tzinfo=datetime.timezone.utc),
#   1531299429814308870,
#   "First migrants 'face being handed Rwanda deportation notices THIS WEEK' https://t.co/j5EgEDtGfz",
#   'DailyMailUK',
#   46],
#  [datetime.datetime(2022, 5, 30, 15, 5, 3, tzinfo=datetime.timezone.utc),
#   1531290597314666499,
#   "Migrants 'face being handed Rwanda deportation notices THIS WEEK' https://t.co/sbIfbCwi6n",
#   'MailOnline',
#   60],
#  [datetime.datetime(2022, 5, 27, 14, 30, 6, tzinfo=datetime.timezone.utc),
#   1530194638329495557,
#   'More than a million foreign nationals were offered visas to live in the UK last year https://t.co/Q8mkNKlSxn',
#   'DailyMailUK',
#   3],
#  [datetime.datetime(2022, 5, 27, 11, 27, 27, tzinfo=datetime.timezone.utc),
#   1530148672876470272,
#   'NATO scramble jets to intercept Russian plane near Finnish border amid tensions https://t.co/Ws8if82QBp',
#   'TheSun',
#   14],
#  [datetime.datetime(2022, 5, 27, 10, 35, 39, tzinfo=datetime.timezone.utc),
#   1530135639173255170,
#   'UK immigration SURGE: Visas now staggering 145% HIGHER than 2021 as Tories turn on Patel \nhttps://t.co/WEbjjb9CIU',
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 5, 27, 6, 15, 36, tzinfo=datetime.timezone.utc),
#   1530070195804557313,
#   'UK immigration SURGE: Visas now staggering 145% HIGHER than 2021 as Tories turn on Patel\nhttps://t.co/WEbjjb9CIU',
#   'Daily_Express',
#   7],
#  [datetime.datetime(2022, 5, 27, 3, 56, 5, tzinfo=datetime.timezone.utc),
#   1530035083675111436,
#   "'Absolute disgrace!' Boris blasted by Brit amid visa plea for autistic Ukrainian boy https://t.co/MKXHmxGbHF",
#   'Daily_Express',
#   3],
#  [datetime.datetime(2022, 5, 27, 2, 44, 3, tzinfo=datetime.timezone.utc),
#   1530016958078394372,
#   "BBC QT guests lock horns over United Ireland in threat to UK - 'A border poll is coming!' https://t.co/EuziQ5nntl",
#   'Daily_Express',
#   0],
#  [datetime.datetime(2022, 5, 27, 1, 41, 22, tzinfo=datetime.timezone.utc),
#   1530001181673652238,
#   'Mystery as tortured body of priest and second man found near Mexico border https://t.co/msUPuIFoLx',
#   'TheSun',
#   4],
#  [datetime.datetime(2022, 5, 26, 20, 20, 9, tzinfo=datetime.timezone.utc),
#   1529920344768794644,
#   'PICTURED: Bullet-grazed hat worn by border agent during shootout at Texas school https://t.co/2nyAkjxg3O',
#   'MailOnline',
#   4],
#  [datetime.datetime(2022, 5, 26, 12, 35, 4, tzinfo=datetime.timezone.utc),
#   1529803301063106560,
#   'PICTURED: Bullet-grazed hat worn by border agent during shootout at Texas school https://t.co/HTsp9pybTD',
#   'MailOnline',
#   9],
#  [datetime.datetime(2022, 5, 26, 12, 17, 3, tzinfo=datetime.timezone.utc),
#   1529798769113542656,
#   'UK immigration SURGE: Visas now staggering 145% HIGHER than 2021 as Tories turn on Patel\nhttps://t.co/WEbjjb9CIU',
#   'Daily_Express',
#   9],
#  [datetime.datetime(2022, 5, 26, 12, 1, 47, tzinfo=datetime.timezone.utc),
#   1529794928083144705,
#   'Mystery as tortured body of priest and second man found near Mexico border https://t.co/m3TFPofH1a',
#   'TheSun',
#   2],
#  [datetime.datetime(2022, 5, 25, 23, 0, 10, tzinfo=datetime.timezone.utc),
#   1529598225027682304,
#   "Prince Charles urges Ukrainian refugees to 'keep praying' during a visit to centre in Bucharest https://t.co/oqRm0zwuPe",
#   'MailOnline',
#   17],
#  [datetime.datetime(2022, 5, 25, 18, 42, 31, tzinfo=datetime.timezone.utc),
#   1529533388914302976,
#   "Prince Charles urges Ukraine refugees to 'keep praying' during a visit to centre in Bucharest https://t.co/S4yzwLwDTk",
#   'DailyMailUK',
#   19],
#  [datetime.datetime(2022, 5, 25, 18, 42, 5, tzinfo=datetime.timezone.utc),
#   1529533279745019909,
#   "Prince Charles urges Ukraine refugees to 'keep praying' during a visit to centre in Bucharest https://t.co/2FM4X4eyey",
#   'MailOnline',
#   16],
#  [datetime.datetime(2022, 5, 25, 18, 0, 10, tzinfo=datetime.timezone.utc),
#   1529522729229209602,
#   'Boris Becker moved to prison for foreign criminals facing deportation https://t.co/bRN48lcHY8',
#   'DailyMailUK',
#   4],
#  [datetime.datetime(2022, 5, 25, 17, 2, 53, tzinfo=datetime.timezone.utc),
#   1529508312277991429,
#   '🇺🇦 How to send money back to Ukraine\n🇺🇦 What is a Refugee Integration Loan?\n🇺🇦 Easy ways to help Ukrainians settle into life in Britain\nGet the Ukrainians in the UK briefing 👇\nhttps://t.co/1Rzjle8AtQ https://t.co/gbXBlKV3dS',
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 5, 25, 15, 41, 55, tzinfo=datetime.timezone.utc),
#   1529487939625005059,
#   "We're thrilled to welcome back @CameronDLWalker to join Assistant Head of Social @pandoraforsyth for the #RoyalRoundUp. Set your clocks ⏰ and tune in tomorrow at 3.15pm to hear the latest on #royals 'opening up their homes' to Ukrainian refugees 👑🇺🇦\n\nhttps://t.co/4MwfkbVF9H https://t.co/sMoPAFjTmB",
#   'Daily_Express',
#   16],
#  [datetime.datetime(2022, 5, 25, 12, 20, 7, tzinfo=datetime.timezone.utc),
#   1529437152043585536,
#   'Boris Becker moved to prison for foreign criminals facing deportation https://t.co/DB49dTdRWY',
#   'DailyMailUK',
#   9],
#  [datetime.datetime(2022, 5, 25, 8, 10, 7, tzinfo=datetime.timezone.utc),
#   1529374239119265793,
#   'Boris Becker moved to prison for foreign criminals facing deportation https://t.co/B46HhlEjsW',
#   'DailyMailUK',
#   11],
#  [datetime.datetime(2022, 5, 25, 5, 0, 6, tzinfo=datetime.timezone.utc),
#   1529326421079883777,
#   'FBI informants uncover ISIS George W. Bush assassination plot from asylum seeker in Ohio https://t.co/gTiHB1gmRq',
#   'MailOnline',
#   17],
#  [datetime.datetime(2022, 5, 24, 14, 48, 30, tzinfo=datetime.timezone.utc),
#   1529112106225831936,
#   'More than 2,600 Channel migrants have arrived in UK in May https://t.co/KEo2yjw5vA',
#   'DailyMailUK',
#   6],
#  [datetime.datetime(2022, 5, 24, 14, 10, 52, tzinfo=datetime.timezone.utc),
#   1529102637970366465,
#   "'Thank you BREXIT' Remoaner Jon Snow blames hour-long visa wait on EU exit in bizarre rant #Brexit #EuropeanUnion \nhttps://t.co/QCjlqXpFDm",
#   'Daily_Express',
#   8],
#  [datetime.datetime(2022, 5, 24, 12, 0, 5, tzinfo=datetime.timezone.utc),
#   1529069724465782785,
#   "Europe faces 'huge migration problem' sparked by African food shortages https://t.co/8NCdSLlR0c",
#   'MailOnline',
#   12],
#  [datetime.datetime(2022, 5, 23, 22, 0, 6, tzinfo=datetime.timezone.utc),
#   1528858336506036226,
#   "Ukrainian refugee who ran off with British man blames his 'two-faced' wife https://t.co/I9Z2HMdEH2",
#   'DailyMailUK',
#   7],
#  [datetime.datetime(2022, 5, 23, 17, 40, 9, tzinfo=datetime.timezone.utc),
#   1528792914586918912,
#   "Ukrainian refugee who ran off with British man blames his 'two-faced' wife https://t.co/AjxqKu0U6m",
#   'DailyMailUK',
#   16],
#  [datetime.datetime(2022, 5, 23, 17, 30, 6, tzinfo=datetime.timezone.utc),
#   1528790385350348803,
#   "Ukrainian refugee who ran off with British man blames his 'two-faced' wife https://t.co/gNWFHCxhmA",
#   'MailOnline',
#   11],
#  [datetime.datetime(2022, 5, 23, 14, 10, 5, tzinfo=datetime.timezone.utc),
#   1528740051768721410,
#   "Ukrainian refugee who ran off with British man blames his 'two-faced' wife https://t.co/bQmW8OI70i",
#   'MailOnline',
#   7],
#  [datetime.datetime(2022, 5, 23, 14, 4, 51, tzinfo=datetime.timezone.utc),
#   1528738736200105986,
#   "Putin's plan to 'cause African famine' in bid to trigger new refugee wave in the West\nhttps://t.co/HJwBQckfs1",
#   'Daily_Express',
#   3],
#  [datetime.datetime(2022, 5, 23, 12, 50, 6, tzinfo=datetime.timezone.utc),
#   1528719924839043073,
#   "Ukrainian refugee who ran off with British man blames his 'two-faced' wife https://t.co/XJ71u5t8n2",
#   'DailyMailUK',
#   7],
#  [datetime.datetime(2022, 5, 23, 12, 40, 7, tzinfo=datetime.timezone.utc),
#   1528717411557462020,
#   "Ukrainian refugee who ran off with British man blames his 'two-faced' wife https://t.co/ogmSw5fc0W",
#   'MailOnline',
#   13],
#  [datetime.datetime(2022, 5, 23, 12, 0, 5, tzinfo=datetime.timezone.utc),
#   1528707334775930880,
#   'Number of migrants to arrive in UK this year surpasses 9,000 https://t.co/Yn020lC2H3',
#   'DailyMailUK',
#   7],
#  [datetime.datetime(2022, 5, 23, 8, 49, 35, tzinfo=datetime.timezone.utc),
#   1528659393553784833,
#   "'Bull****!' Ukrainian refugee fires back after being stuck in love triangle with UK hosts https://t.co/VzFAulYa8C",
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 5, 23, 8, 0, 10, tzinfo=datetime.timezone.utc),
#   1528646959858429952,
#   "Ukrainian refugee who ran off with British man blames his 'two-faced' wife https://t.co/UAURGX75Cy",
#   'DailyMailUK',
#   9],
#  [datetime.datetime(2022, 5, 23, 7, 40, 1, tzinfo=datetime.timezone.utc),
#   1528641887816515586,
#   "Ukrainian refugee who ran off with British man blames his 'two-faced' wife https://t.co/7H1Qrd2vU8",
#   'MailOnline',
#   17],
#  [datetime.datetime(2022, 5, 23, 0, 0, 6, tzinfo=datetime.timezone.utc),
#   1528526146140258306,
#   'Father-of-two is pictured with his Ukrainian refugee girlfriend https://t.co/WhZbEOizkH',
#   'MailOnline',
#   7],
#  [datetime.datetime(2022, 5, 22, 22, 40, 9, tzinfo=datetime.timezone.utc),
#   1528506027280302081,
#   'Anger of jilted mother whose partner ran off with Ukrainian refugee https://t.co/YL6tIl8mK9',
#   'MailOnline',
#   16],
#  [datetime.datetime(2022, 5, 22, 22, 40, 8, tzinfo=datetime.timezone.utc),
#   1528506019831324672,
#   'Father-of-two is pictured with his Ukrainian refugee girlfriend https://t.co/TFmDrmjGJj',
#   'DailyMailUK',
#   10],
#  [datetime.datetime(2022, 5, 22, 22, 0, 6, tzinfo=datetime.timezone.utc),
#   1528495946111262720,
#   'Father-of-two is pictured with his Ukrainian refugee girlfriend https://t.co/IRRH1zRfih',
#   'MailOnline',
#   36],
#  [datetime.datetime(2022, 5, 22, 20, 20, 6, tzinfo=datetime.timezone.utc),
#   1528470779586912258,
#   'Home Office red tape locking vulnerable Ukrainian refugees out of UK https://t.co/x8xt8QtAbe',
#   'DailyMailUK',
#   13],
#  [datetime.datetime(2022, 5, 22, 19, 20, 4, tzinfo=datetime.timezone.utc),
#   1528455675294138369,
#   "EXCLUSIVE: Channel migrants are 'asking to be returned home and not to African centres' https://t.co/1m8cm4rTjz",
#   'DailyMailUK',
#   27],
#  [datetime.datetime(2022, 5, 22, 18, 20, 10, tzinfo=datetime.timezone.utc),
#   1528440597853491202,
#   'Anger of jilted mother whose partner ran off with Ukrainian refugee https://t.co/IUBSSEkvh8',
#   'DailyMailUK',
#   12],
#  [datetime.datetime(2022, 5, 22, 17, 20, 3, tzinfo=datetime.timezone.utc),
#   1528425470726918145,
#   'Anger of jilted mother whose partner ran off with Ukrainian refugee https://t.co/3SEE7Judu2',
#   'MailOnline',
#   22],
#  [datetime.datetime(2022, 5, 22, 17, 0, 7, tzinfo=datetime.timezone.utc),
#   1528420455253696513,
#   "EXCLUSIVE: Channel migrants are 'asking to be returned home and not to African centres' https://t.co/JEwguLYd07",
#   'DailyMailUK',
#   23],
#  [datetime.datetime(2022, 5, 22, 16, 23, 5, tzinfo=datetime.timezone.utc),
#   1528411132112818177,
#   'Another group of migrants including young children arrive in UK https://t.co/CaR3D2a1Qv',
#   'DailyMailUK',
#   9],
#  [datetime.datetime(2022, 5, 22, 14, 15, 3, tzinfo=datetime.timezone.utc),
#   1528378914082541570,
#   "EXCLUSIVE: Channel migrants are 'asking to be returned home and not to African centres' https://t.co/Gp3lsfXHcV",
#   'DailyMailUK',
#   35],
#  [datetime.datetime(2022, 5, 22, 13, 50, 3, tzinfo=datetime.timezone.utc),
#   1528372623633268736,
#   'Anger of jilted mother whose partner ran off with Ukrainian refugee https://t.co/lXRWq285cg',
#   'MailOnline',
#   18],
#  [datetime.datetime(2022, 5, 22, 13, 30, 13, tzinfo=datetime.timezone.utc),
#   1528367632134864896,
#   'Father-of-two is pictured with his Ukrainian refugee girlfriend https://t.co/r1GNy4KhKx',
#   'MailOnline',
#   25],
#  [datetime.datetime(2022, 5, 22, 13, 30, 13, tzinfo=datetime.timezone.utc),
#   1528367631958433792,
#   'Father-of-two is pictured with his Ukrainian refugee girlfriend https://t.co/tPU4vJ1tlU',
#   'DailyMailUK',
#   8],
#  [datetime.datetime(2022, 5, 22, 11, 10, 5, tzinfo=datetime.timezone.utc),
#   1528332366644658182,
#   "EXCLUSIVE: Channel migrants are 'asking to be returned home and not to African centres' https://t.co/iXnYXwQ3hL",
#   'MailOnline',
#   17],
#  [datetime.datetime(2022, 5, 22, 10, 43, 35, tzinfo=datetime.timezone.utc),
#   1528325695159652352,
#   "Mum whose partner ran off with Ukrainian refugee claims 'she was after him from day one' https://t.co/jJeqxICMle",
#   'Daily_Express',
#   5],
#  [datetime.datetime(2022, 5, 22, 9, 20, 7, tzinfo=datetime.timezone.utc),
#   1528304690433236992,
#   'Anger of jilted mother whose partner ran off with Ukrainian refugee https://t.co/NdQQdyMFML',
#   'MailOnline',
#   21],
#  [datetime.datetime(2022, 5, 22, 9, 0, 6, tzinfo=datetime.timezone.utc),
#   1528299653501952002,
#   'Home Office red tape locking vulnerable Ukrainian refugees out of UK https://t.co/EXKjjahgGc',
#   'DailyMailUK',
#   7],
#  [datetime.datetime(2022, 5, 22, 8, 15, 5, tzinfo=datetime.timezone.utc),
#   1528288324624035840,
#   "EXCLUSIVE: Channel migrants are 'asking to be returned home and not to African centres' https://t.co/FV7S54vFpC",
#   'DailyMailUK',
#   70],
#  [datetime.datetime(2022, 5, 22, 7, 25, 11, tzinfo=datetime.timezone.utc),
#   1528275765783146496,
#   'Anger of jilted mother whose partner ran off with Ukrainian refugee https://t.co/oVWfuq0w7H',
#   'DailyMailUK',
#   30],
#  [datetime.datetime(2022, 5, 22, 3, 1, 49, tzinfo=datetime.timezone.utc),
#   1528209487483613186,
#   "Fury over plans to make former RAF base in tiny village asylum centre 'wrong plan, wrong place!' https://t.co/0GZjb4x4Yl",
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 5, 21, 22, 40, 5, tzinfo=datetime.timezone.utc),
#   1528143621056258049,
#   'Father-of-two DUMPS his partner after falling for 22-year-old Ukrainian refugee https://t.co/SWivm6NQhx',
#   'DailyMailUK',
#   8],
#  [datetime.datetime(2022, 5, 21, 22, 0, 6, tzinfo=datetime.timezone.utc),
#   1528133557092290560,
#   'Father-of-two DUMPS his partner after falling for 22-year-old Ukrainian refugee https://t.co/LcON8mINBI',
#   'MailOnline',
#   29],
#  [datetime.datetime(2022, 5, 21, 21, 40, 7, tzinfo=datetime.timezone.utc),
#   1528128530525179907,
#   'Queen and Royal Family secretly open their doors to Ukrainian refugees https://t.co/qZQYJkZyNL',
#   'DailyMailUK',
#   244],
#  [datetime.datetime(2022, 5, 21, 17, 40, 9, tzinfo=datetime.timezone.utc),
#   1528068141896589312,
#   'Queen and Royal Family secretly open their doors to Ukrainian refugees https://t.co/UDN9z6PTn1',
#   'DailyMailUK',
#   64],
#  [datetime.datetime(2022, 5, 21, 17, 31, 4, tzinfo=datetime.timezone.utc),
#   1528065856131022848,
#   "Royal family 'secretly opened doors to Ukrainian refugees' escaping war\nhttps://t.co/3OjeLyL6MZ",
#   'TheSun',
#   23],
#  [datetime.datetime(2022, 5, 21, 17, 0, 11, tzinfo=datetime.timezone.utc),
#   1528058082626097152,
#   'Father-of-two DUMPS his partner after falling for 22-year-old Ukrainian refugee https://t.co/krS0CRqzQB',
#   'DailyMailUK',
#   7],
#  [datetime.datetime(2022, 5, 21, 16, 45, 55, tzinfo=datetime.timezone.utc),
#   1528054491865661444,
#   "'I dumped partner for Ukrainian refugee days after she moved in with us' https://t.co/PzJEeUhW8K",
#   'TheSun',
#   19],
#  [datetime.datetime(2022, 5, 21, 16, 0, 6, tzinfo=datetime.timezone.utc),
#   1528042961375739906,
#   'Father-of-two DUMPS his partner after falling for 22-year-old Ukrainian refugee https://t.co/zxoIEcQOsV',
#   'MailOnline',
#   23],
#  [datetime.datetime(2022, 5, 21, 13, 50, 18, tzinfo=datetime.timezone.utc),
#   1528010297482657793,
#   'Father-of-two leaves wife for Ukrainian refugee who moved in to family home 10 days before\n\nhttps://t.co/uISGVQpjsC https://t.co/r6LJY132BP',
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 5, 21, 13, 0, 2, tzinfo=datetime.timezone.utc),
#   1527997645322653696,
#   'Father-of-two DUMPS his partner after falling for 22-year-old Ukrainian refugee https://t.co/8pQ3gIDfxs',
#   'DailyMailUK',
#   2],
#  [datetime.datetime(2022, 5, 21, 12, 50, 2, tzinfo=datetime.timezone.utc),
#   1527995131382616066,
#   'Father-of-two DUMPS his partner after falling for 22-year-old Ukrainian refugee https://t.co/fMB7J3zCOB',
#   'MailOnline',
#   59],
#  [datetime.datetime(2022, 5, 21, 12, 0, 10, tzinfo=datetime.timezone.utc),
#   1527982581165314048,
#   'Queen and Royal Family secretly open their doors to Ukrainian refugees https://t.co/yaC6ZALi2Q',
#   'DailyMailUK',
#   189],
#  [datetime.datetime(2022, 5, 21, 11, 30, 5, tzinfo=datetime.timezone.utc),
#   1527975008244576258,
#   'Queen and Royal Family secretly open their doors to Ukrainian refugees https://t.co/v7bdJq9l1F',
#   'MailOnline',
#   38],
#  [datetime.datetime(2022, 5, 21, 11, 0, 7, tzinfo=datetime.timezone.utc),
#   1527967469528403969,
#   'Father-of-two DUMPS his partner after falling for 22-year-old Ukrainian refugee https://t.co/ZAdEvBfXQB',
#   'DailyMailUK',
#   28],
#  [datetime.datetime(2022, 5, 21, 10, 50, 6, tzinfo=datetime.timezone.utc),
#   1527964946100887552,
#   'Father-of-two DUMPS his partner after falling for 22-year-old Ukrainian refugee https://t.co/krvWSxNUvr',
#   'MailOnline',
#   52],
#  [datetime.datetime(2022, 5, 21, 8, 0, 4, tzinfo=datetime.timezone.utc),
#   1527922156348264448,
#   'British aid worker is stuck in Poland with hundreds of Ukrainian refugees https://t.co/5xsvH3jiqP',
#   'MailOnline',
#   10],
#  [datetime.datetime(2022, 5, 21, 7, 30, 10, tzinfo=datetime.timezone.utc),
#   1527914632903548928,
#   'Queen and Royal Family secretly open their doors to Ukrainian refugees https://t.co/4eWPrqZoBn',
#   'DailyMailUK',
#   95],
#  [datetime.datetime(2022, 5, 21, 7, 0, 8, tzinfo=datetime.timezone.utc),
#   1527907076109914112,
#   'Homeland Security fears it may need $2 BILLION in extra funding to help deal with the migrant surge https://t.co/gPjCy7RIQR',
#   'MailOnline',
#   13],
#  [datetime.datetime(2022, 5, 21, 6, 51, 48, tzinfo=datetime.timezone.utc),
#   1527904977603239936,
#   "Royal family 'secretly opened doors to Ukrainian refugees' escaping war\nhttps://t.co/Ny3cWUxCLI",
#   'TheSun',
#   19],
#  [datetime.datetime(2022, 5, 20, 23, 56, 12, tzinfo=datetime.timezone.utc),
#   1527800387796877315,
#   'Queen and the Royal Family have secretly opened their doors to Ukrainian refugees fleeing their homeland https://t.co/J0DwTRK2Ou',
#   'MailOnline',
#   72],
#  [datetime.datetime(2022, 5, 20, 20, 43, 8, tzinfo=datetime.timezone.utc),
#   1527751802157932545,
#   "Front page: Royal Family secretly house refugees #TomorrowsPapersToday\n\nRishi and his wife's millions: https://t.co/wcz3TUJXxE https://t.co/AyWo5eUp6f",
#   'Daily_Express',
#   9],
#  [datetime.datetime(2022, 5, 20, 20, 33, 58, tzinfo=datetime.timezone.utc),
#   1527749495840198656,
#   "On tomorrow's front page: 'I took in a Ukrainian refugee to live with my wife and me then ran off with her after two weeks - we're in love'  https://t.co/qKey2dKthG https://t.co/gRquI9tWkk",
#   'TheSun',
#   48],
#  [datetime.datetime(2022, 5, 20, 20, 21, 50, tzinfo=datetime.timezone.utc),
#   1527746443443838978,
#   "'I took in a Ukrainian refugee to live with my wife and me - then ran off with her after two weeks'  https://t.co/pIsATFgWgp",
#   'TheSun',
#   69],
#  [datetime.datetime(2022, 5, 20, 18, 0, 5, tzinfo=datetime.timezone.utc),
#   1527710767260348418,
#   'Migrants pour through gaps in US border wall with Title 42 set to expire Monday https://t.co/vGaicEcDdp',
#   'MailOnline',
#   14],
#  [datetime.datetime(2022, 5, 19, 21, 5, 3, tzinfo=datetime.timezone.utc),
#   1527394931408609280,
#   "Sudanese migrant told he's going to Rwanda says he will KILL himself rather than be sent back to Africa https://t.co/AH640MMTIA",
#   'MailOnline',
#   31],
#  [datetime.datetime(2022, 5, 19, 19, 39, 6, tzinfo=datetime.timezone.utc),
#   1527373298593476624,
#   "Sudanese migrant told he's going to Rwanda says he will KILL himself rather than be sent back to Africa https://t.co/Vy2legZv69",
#   'DailyMailUK',
#   21],
#  [datetime.datetime(2022, 5, 19, 17, 37, 5, tzinfo=datetime.timezone.utc),
#   1527342592525881344,
#   "Sudanese migrant told he's going to Rwanda says he will KILL himself rather than be sent back to Africa https://t.co/MdM0CGQk6k",
#   'DailyMailUK',
#   52],
#  [datetime.datetime(2022, 5, 19, 4, 8, 32, tzinfo=datetime.timezone.utc),
#   1527139116785274880,
#   "'Out of control!' Government slammed as visas issued to non-EU migrants reach record high https://t.co/VQCCeyhBoa",
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 5, 18, 20, 6, tzinfo=datetime.timezone.utc),
#   1527017680779325440,
#   'Archaeology breakthrough: Underground city uncovered as site of early christian refugees https://t.co/Cb6LNXs4LH https://t.co/mqMSCEXr7g',
#   'Daily_Express',
#   3],
#  [datetime.datetime(2022, 5, 18, 14, 0, 11, tzinfo=datetime.timezone.utc),
#   1526925620340563968,
#   'Convicted child sex attackers, drug dealers and thugs are sent on deportation fight to Jamaica https://t.co/CmWbkMBDp5',
#   'DailyMailUK',
#   17],
#  [datetime.datetime(2022, 5, 18, 10, 38, 2, tzinfo=datetime.timezone.utc),
#   1526874749548343296,
#   'The rest of the UK has relaxed the rules for Ukrainian refugees https://t.co/wZBP0yAUBp',
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 5, 18, 10, 6, tzinfo=datetime.timezone.utc),
#   1526866685877026817,
#   'Archaeology breakthrough: Underground city uncovered as site of early christian refugees https://t.co/Cb6LNXJFDf https://t.co/aVVQ2F5rgF',
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 5, 18, 9, 6, tzinfo=datetime.timezone.utc),
#   1526851585787060224,
#   'Archaeology breakthrough: Underground city uncovered as site of early christian refugees https://t.co/Cb6LNXJFDf https://t.co/Vltwj7fq1N',
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 5, 17, 23, 30, 8, tzinfo=datetime.timezone.utc),
#   1526706663725711362,
#   'Injuries suffered while climbing over US-Mexico border wall soared by 460% after Trump ordered height of barrier to be increased https://t.co/4oAEKyTYKc',
#   'MailOnline',
#   29],
#  [datetime.datetime(2022, 5, 17, 22, 40, tzinfo=datetime.timezone.utc),
#   1526694048144060416,
#   'Eurovision winners sing at Polish border as they returned to Ukraine https://t.co/Uz4uTLXRyA',
#   'TheSun',
#   37],
#  [datetime.datetime(2022, 5, 17, 21, 46, 18, tzinfo=datetime.timezone.utc),
#   1526680535925460992,
#   'Archaeology breakthrough: Underground city uncovered as site of early christian refugees https://t.co/Cb6LNXs4LH https://t.co/Q8UX6jrbt8',
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 5, 17, 18, 0, tzinfo=datetime.timezone.utc),
#   1526623584692539393,
#   'Eurovision winners sing at Polish border as they returned to Ukraine https://t.co/tEe04PSzfU',
#   'TheSun',
#   32],
#  [datetime.datetime(2022, 5, 17, 15, 49, 17, tzinfo=datetime.timezone.utc),
#   1526590688745381888,
#   'More than 300 migrants arrive in UK as crossings continue for FOURTH day in a row https://t.co/yGGJQGFGXW',
#   'MailOnline',
#   19],
#  [datetime.datetime(2022, 5, 17, 13, 41, 42, tzinfo=datetime.timezone.utc),
#   1526558579276365829,
#   '‘Human phoenix’ Sacha gets set for latest adventure - months after horrific accident @sachadench @C_no_borders @JoannaLumleyUK\n\nhttps://t.co/pEXxn7NgdT',
#   'Daily_Express',
#   0],
#  [datetime.datetime(2022, 5, 17, 11, 25, 5, tzinfo=datetime.timezone.utc),
#   1526524198809743361,
#   'More migrants arrive in Kent as crossings continue for FOURTH day in a row https://t.co/XTmcm1h37y',
#   'MailOnline',
#   12],
#  [datetime.datetime(2022, 5, 17, 10, 30, tzinfo=datetime.timezone.utc),
#   1526510339315052544,
#   'Eurovision winners sing at Polish border as they returned to Ukraine https://t.co/9HKgfPvaSM',
#   'TheSun',
#   41],
#  [datetime.datetime(2022, 5, 17, 10, 15, 5, tzinfo=datetime.timezone.utc),
#   1526506584263860225,
#   'More migrants arrive in Kent as crossings continue for FOURTH day in a row https://t.co/gZAdf75MO2',
#   'DailyMailUK',
#   15],
#  [datetime.datetime(2022, 5, 17, 6, 0, tzinfo=datetime.timezone.utc),
#   1526442391862923265,
#   "Russia 'deploys nuke missiles' to border with Finland in chilling threat over country's NATO bid https://t.co/tOm8kzDCxL",
#   'TheSun',
#   21],
#  [datetime.datetime(2022, 5, 16, 23, 27, 37, tzinfo=datetime.timezone.utc),
#   1526343644667645953,
#   'Russian president is making tactical decisions as Ukrainian forces drives his army BACK to the border https://t.co/L1JgDv3kp0',
#   'MailOnline',
#   12],
#  [datetime.datetime(2022, 5, 16, 22, 30, tzinfo=datetime.timezone.utc),
#   1526329143641530369,
#   "Russia 'deploys nuke missiles' to border with Finland in chilling threat over country's NATO bid https://t.co/hii0Yhkvf5",
#   'TheSun',
#   14],
#  [datetime.datetime(2022, 5, 16, 20, 40, 6, tzinfo=datetime.timezone.utc),
#   1526301485205704707,
#   "Russia 'moves nuclear-capable missiles to Finland's border' https://t.co/eyeWpKNT9G https://t.co/X4WDIPTQWS",
#   'MailOnline',
#   46],
#  [datetime.datetime(2022, 5, 16, 18, 45, 7, tzinfo=datetime.timezone.utc),
#   1526272550497574912,
#   'Asylum-seeker with Beatles tattoo avoids deportation after arguing she would be at risk if sent home https://t.co/yJDERkQ4D8',
#   'DailyMailUK',
#   5],
#  [datetime.datetime(2022, 5, 16, 18, 0, tzinfo=datetime.timezone.utc),
#   1526261195845603329,
#   "Russia 'deploys nuke missiles' to border with Finland in chilling threat over country's NATO bid https://t.co/Z3Fnbnr83W",
#   'TheSun',
#   14],
#  [datetime.datetime(2022, 5, 16, 16, 59, 2, tzinfo=datetime.timezone.utc),
#   1526245855682039809,
#   "Proof the Rwanda asylum-seeker plan isn't working? Over 600 migrants arrived in UK over the weekend https://t.co/VPRZDbtqTr",
#   'DailyMailUK',
#   24],
#  [datetime.datetime(2022, 5, 16, 16, 28, 18, tzinfo=datetime.timezone.utc),
#   1526238118164193283,
#   'Asylum-seeker with Beatles tattoo avoids deportation after arguing she would be at risk of harm https://t.co/iT3limDWpT',
#   'DailyMailUK',
#   12],
#  [datetime.datetime(2022, 5, 16, 15, 0, 2, tzinfo=datetime.timezone.utc),
#   1526215904912195584,
#   '#Brexit outrage: UK fishing boats treated as foreigners in OWN waters under hated deal #EuropeanUnion #NorthernIrelandProtocol \n\nhttps://t.co/qXfB6bKyt2',
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 5, 16, 14, 5, 28, tzinfo=datetime.timezone.utc),
#   1526202174484762624,
#   'Hundreds more migrants cross English Channel over weekend despite Rwanda deterrent\nhttps://t.co/XU52WDoWWR',
#   'Daily_Express',
#   9],
#  [datetime.datetime(2022, 5, 16, 13, 43, 23, tzinfo=datetime.timezone.utc),
#   1526196616822243328,
#   'Horror as Lukashenko orders first wave of Belarusian troops direct to Ukraine border\n\nhttps://t.co/hJCWHCrfOl https://t.co/jGdAnNuG9c',
#   'Daily_Express',
#   8],
#  [datetime.datetime(2022, 5, 16, 13, 0, 1, tzinfo=datetime.timezone.utc),
#   1526185704509779970,
#   '#Brexit outrage: UK fishing boats treated as foreigners in OWN waters under hated deal #EuropeanUnion #NorthernIrelandProtocol \n\nhttps://t.co/jJvFU95abl',
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 5, 16, 12, 0, 2, tzinfo=datetime.timezone.utc),
#   1526170606646857728,
#   "Russia 'deploys nuke missiles' to border with Finland in chilling threat over country's NATO bid https://t.co/QPJOgnTnTg",
#   'TheSun',
#   10],
#  [datetime.datetime(2022, 5, 16, 11, 50, 5, tzinfo=datetime.timezone.utc),
#   1526168102605570048,
#   "Russia 'moves nuclear-capable missiles to Finland's border' https://t.co/VYwLALRxeN https://t.co/PDYQdMTB4s",
#   'MailOnline',
#   46],
#  [datetime.datetime(2022, 5, 16, 11, 13, tzinfo=datetime.timezone.utc),
#   1526158771529125896,
#   'As Aldi and Asos join employers offering Ukrainian refugees a route back to work in Britain, Ukrainian Olya Kosousova, a senior project manager on the News UK tech team, shares her top tips on how to help Ukrainians settle in https://t.co/wZ8VVw9DdA',
#   'TheSun',
#   7],
#  [datetime.datetime(2022, 5, 16, 10, 58, 22, tzinfo=datetime.timezone.utc),
#   1526155088510783489,
#   '#Brexit outrage: UK fishing boats treated as foreigners in OWN waters under hated deal #EuropeanUnion #NorthernIrelandProtocol @FreeBritain\n\nhttps://t.co/qXfB6bKyt2',
#   'Daily_Express',
#   14],
#  [datetime.datetime(2022, 5, 16, 10, 40, 9, tzinfo=datetime.timezone.utc),
#   1526150503213715457,
#   "Russia 'moves nuclear-capable missiles to Finland's border' https://t.co/0XJTh4PQYD https://t.co/RasJpIuxeV",
#   'MailOnline',
#   34],
#  [datetime.datetime(2022, 5, 16, 10, 10, 1, tzinfo=datetime.timezone.utc),
#   1526142920465735683,
#   'Ukrainian troops pose on Russian border as Kharkiv attack crumbles https://t.co/xCqgftXgxV',
#   'MailOnline',
#   39],
#  [datetime.datetime(2022, 5, 16, 6, 1, 49, tzinfo=datetime.timezone.utc),
#   1526080461193326593,
#   'Russia threatens to deploy tactical nuclear weapons on its European border https://t.co/hbWMPpHQ38',
#   'MailOnline',
#   58],
#  [datetime.datetime(2022, 5, 15, 11, 48, tzinfo=datetime.timezone.utc),
#   1525805190766551040,
#   '‘How dare he!’ Fury at ex-EU chief over Brexit border swipe ‘Put in your own territory’ \nhttps://t.co/pBziWph1ny',
#   'Daily_Express',
#   6],
#  [datetime.datetime(2022, 5, 15, 11, 28, 35, tzinfo=datetime.timezone.utc),
#   1525800303618101248,
#   '‘How dare he!’ Fury at ex-EU chief over Brexit border swipe ‘Put in your own territory’\nhttps://t.co/pBziWph1ny',
#   'Daily_Express',
#   5],
#  [datetime.datetime(2022, 5, 15, 7, 46, 19, tzinfo=datetime.timezone.utc),
#   1525744371638882305,
#   'Qatar World Cup migrant workers ‘are infiltrated by informants to spy on whistleblowers trying to expose exploitation’\nhttps://t.co/QAisuppc1U',
#   'TheSun',
#   15],
#  [datetime.datetime(2022, 5, 14, 22, 45, 7, tzinfo=datetime.timezone.utc),
#   1525608172781813761,
#   'Afghan asylum seeker who sexually assaulted two women and battered three with a hammer in terrifying West End rampage begins 18 years behind bars https://t.co/ajCBJvNzAr',
#   'DailyMailUK',
#   25],
#  [datetime.datetime(2022, 5, 14, 21, 30, 2, tzinfo=datetime.timezone.utc),
#   1525589276297154560,
#   "Another 50 migrants arrive in Dover despite Boris Johnson's get-tough pledge https://t.co/Ih2kSgQHSo",
#   'DailyMailUK',
#   19],
#  [datetime.datetime(2022, 5, 14, 15, 40, 6, tzinfo=datetime.timezone.utc),
#   1525501213420167168,
#   "Another 50 migrants arrive in Dover despite Boris Johnson's get-tough pledge https://t.co/cifoAskR1v",
#   'DailyMailUK',
#   14],
#  [datetime.datetime(2022, 5, 14, 13, 30, 10, tzinfo=datetime.timezone.utc),
#   1525468516106833921,
#   'Afghan asylum seeker who sexually assaulted two women and battered three with a hammer in terrifying West End rampage begins 18 years behind bars https://t.co/8hjliQ3TRw',
#   'DailyMailUK',
#   37],
#  [datetime.datetime(2022, 5, 14, 8, 40, 8, tzinfo=datetime.timezone.utc),
#   1525395524408442880,
#   "Putin's Stalinist deportation plan for 2MILLION Ukrainians https://t.co/BFueZPtu3g",
#   'MailOnline',
#   16],
#  [datetime.datetime(2022, 5, 14, 5, 30, 6, tzinfo=datetime.timezone.utc),
#   1525347701021413377,
#   "Putin's Stalinist deportation plan for 2MILLION Ukrainians: Mail uncovers chilling official blueprint for mass expulsion and 1,310 'transit centres' - drawn up before invasion began https://t.co/7c7rN8WIsp",
#   'MailOnline',
#   28],
#  [datetime.datetime(2022, 5, 14, 5, 0, 3, tzinfo=datetime.timezone.utc),
#   1525340141145190400,
#   'Mannequins dressed up as soldiers have been pictured in the heavily battered Kharkiv days after reports that Ukraine has driven Russian troops back to their own border near the city https://t.co/80Ai5s4SkU',
#   'MailOnline',
#   24],
#  [datetime.datetime(2022, 5, 14, 3, 41, 7, tzinfo=datetime.timezone.utc),
#   1525320276615090177,
#   'At least 11 migrants are found dead and 38 others rescued after wooden vessel capsizes off coast of Puerto Rico https://t.co/GpLN0rrfIK',
#   'MailOnline',
#   12],
#  [datetime.datetime(2022, 5, 13, 23, 58, 25, tzinfo=datetime.timezone.utc),
#   1525264233516105731,
#   "North Yorkshire locals slam 'radio silence' over plan to turn RAF site into asylum seeker processing centre https://t.co/LaKfEfQ82c",
#   'DailyMailUK',
#   5],
#  [datetime.datetime(2022, 5, 13, 20, 0, 37, tzinfo=datetime.timezone.utc),
#   1525204388603736065,
#   'Ukrainian refugees given walking tour of Manchester by volunteers\n\nhttps://t.co/Pww4koRUYd https://t.co/4N1EKK4v6D',
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 5, 13, 18, 58, 53, tzinfo=datetime.timezone.utc),
#   1525188852973019137,
#   'At least 11 migrants are found dead and 38 others rescued after wooden vessel capsizes off coast of Puerto Rico https://t.co/7at7rhKplb',
#   'MailOnline',
#   16],
#  [datetime.datetime(2022, 5, 13, 17, 36, 7, tzinfo=datetime.timezone.utc),
#   1525168020657684484,
#   "North Yorkshire locals slam 'radio silence' over plan to turn RAF site into asylum seeker processing centre https://t.co/B20wwHT1U2",
#   'DailyMailUK',
#   5],
#  [datetime.datetime(2022, 5, 13, 10, 20, 42, tzinfo=datetime.timezone.utc),
#   1525058447783370752,
#   "Russia set to increase 'military presence on border' as Finland joins NATO\nhttps://t.co/OnkfVbI6sk",
#   'Daily_Express',
#   3],
#  [datetime.datetime(2022, 5, 12, 10, 22, 50, tzinfo=datetime.timezone.utc),
#   1524696594502795265,
#   "GB News presenter tears apart Rwanda migration 'plan' - 'Believe it when I see it!'\nhttps://t.co/eU1hNOIEaN",
#   'Daily_Express',
#   0],
#  [datetime.datetime(2022, 5, 12, 7, 0, 1, tzinfo=datetime.timezone.utc),
#   1524645556127244293,
#   'Ukraine says Russia is pushed back from Kharkiv and driven towards the border https://t.co/uDGnOTtkLy',
#   'MailOnline',
#   35],
#  [datetime.datetime(2022, 5, 12, 5, 35, 25, tzinfo=datetime.timezone.utc),
#   1524624266205044736,
#   "'Unable to rule out' Ukrainian refugees fleeing war may be at risk of being sent to Rwanda https://t.co/LoaODvzs0b https://t.co/jX3ptmgWSZ",
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 5, 12, 1, 2, 33, tzinfo=datetime.timezone.utc),
#   1524555595671474176,
#   'Ukraine says Russia is pushed back from Kharkiv and driven towards the border https://t.co/LgB9Q2MCYu',
#   'MailOnline',
#   28],
#  [datetime.datetime(2022, 5, 11, 15, 54, 53, tzinfo=datetime.timezone.utc),
#   1524417772394065920,
#   "Minister hints at MORE asylum deals, suggesting Rwanda 'might not be the last' https://t.co/9qRmpCZ9gL",
#   'DailyMailUK',
#   5],
#  [datetime.datetime(2022, 5, 11, 15, 50, 3, tzinfo=datetime.timezone.utc),
#   1524416553093148672,
#   'First Channel migrants have been told by Priti Patel that they are being sent to Rwanda https://t.co/G1i4GWzMIS',
#   'DailyMailUK',
#   21],
#  [datetime.datetime(2022, 5, 11, 13, 51, 27, tzinfo=datetime.timezone.utc),
#   1524386707591815173,
#   "Lord Frost says UK is being forced to act 'unilaterally' over hated #Brexit trade border\n\nhttps://t.co/S6g3zClAtN",
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 5, 11, 12, 30, 10, tzinfo=datetime.timezone.utc),
#   1524366252663357442,
#   'First Channel migrants have been told by Priti Patel that they are being sent to Rwanda https://t.co/Wcs5tfT9Yd',
#   'DailyMailUK',
#   34],
#  [datetime.datetime(2022, 5, 11, 12, 28, 7, tzinfo=datetime.timezone.utc),
#   1524365736705236992,
#   "Putin's ally amasses troops on Ukraine border fuelling fears Belarus will join war\n\nhttps://t.co/ZgOIL060uK",
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 5, 11, 11, 30, 4, tzinfo=datetime.timezone.utc),
#   1524351126669246466,
#   "Migrants in Britain 'going into HIDING as they fear being sent to Rwanda' https://t.co/DiOPvjVXNx",
#   'DailyMailUK',
#   8],
#  [datetime.datetime(2022, 5, 11, 8, 10, 4, tzinfo=datetime.timezone.utc),
#   1524300796736983040,
#   'First Channel migrants have been told by Priti Patel that they are being sent to Rwanda https://t.co/sQPQxy7Yxu',
#   'DailyMailUK',
#   144],
#  [datetime.datetime(2022, 5, 11, 4, 51, 6, tzinfo=datetime.timezone.utc),
#   1524250723705360384,
#   'New Zealand will FINALLY reopen to the rest of the world in July after some of the strictest Covid border rules on the planet https://t.co/F9wOr08J0a',
#   'MailOnline',
#   125],
#  [datetime.datetime(2022, 5, 11, 0, 0, 8, tzinfo=datetime.timezone.utc),
#   1524177501253246978,
#   'British couples are separated by UK visa backlogs for up to six months https://t.co/0f34dbm43T',
#   'DailyMailUK',
#   3],
#  [datetime.datetime(2022, 5, 10, 22, 50, tzinfo=datetime.timezone.utc),
#   1524159849067532288,
#   '‘Accident waiting to happen’ Brexit warning as farmers sound alarm over border checks\nhttps://t.co/OyDz6zDcmL https://t.co/WGKxX6952D',
#   'Daily_Express',
#   0],
#  [datetime.datetime(2022, 5, 10, 21, 50, tzinfo=datetime.timezone.utc),
#   1524144749640183810,
#   '‘Accident waiting to happen’ Brexit warning as farmers sound alarm over border checks\nhttps://t.co/OyDz6zDcmL https://t.co/9byOmgc9qF',
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 5, 10, 21, 30, 1, tzinfo=datetime.timezone.utc),
#   1524139720292380673,
#   '‘Accident waiting to happen’ Brexit warning as farmers sound alarm over border checks\nhttps://t.co/OyDz6zlBvd https://t.co/hpAEV1jjPI',
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 5, 10, 14, 30, 9, tzinfo=datetime.timezone.utc),
#   1524034057004363777,
#   'British couples are separated by UK visa backlogs for up to six months https://t.co/fliFbmg4kP',
#   'DailyMailUK',
#   5],
#  [datetime.datetime(2022, 5, 10, 10, 10, 3, tzinfo=datetime.timezone.utc),
#   1523968603879575552,
#   'British couples are separated by UK visa backlogs for up to six months https://t.co/ub8Ci3FntT',
#   'DailyMailUK',
#   2],
#  [datetime.datetime(2022, 5, 10, 9, 20, 5, tzinfo=datetime.timezone.utc),
#   1523956030002143233,
#   "EU border chief quits in frustration over 'pro-migrant politicians and NGOs' https://t.co/txRWMldFDX",
#   'MailOnline',
#   13],
#  [datetime.datetime(2022, 5, 10, 8, 55, 1, tzinfo=datetime.timezone.utc),
#   1523949721764732928,
#   'British couples are separated by UK visa backlogs as Home Office says it is concentrating on Ukrainian applications instead https://t.co/dUaJ0ylASD',
#   'MailOnline',
#   8],
#  [datetime.datetime(2022, 5, 10, 7, 10, 4, tzinfo=datetime.timezone.utc),
#   1523923307388616704,
#   'First migrants slated for deportation to Rwanda will be told this week https://t.co/8xXHd88xVw',
#   'DailyMailUK',
#   5],
#  [datetime.datetime(2022, 5, 10, 4, 35, 25, tzinfo=datetime.timezone.utc),
#   1523884388097966080,
#   "Priti Patel says Rwanda asylum plan 'will take time' as she vows to 'take back control' https://t.co/uuyjAF4oiy",
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 5, 10, 3, 32, 2, tzinfo=datetime.timezone.utc),
#   1523868440527884290,
#   "Man 'in handcuffs' among group of migrants landing in Dover https://t.co/jUDDxTjoc3",
#   'DailyMailUK',
#   2],
#  [datetime.datetime(2022, 5, 10, 0, 32, 33, tzinfo=datetime.timezone.utc),
#   1523823271615123457,
#   'First migrants slated for deportation to Rwanda will be told this week https://t.co/QJeFiVNB5w',
#   'DailyMailUK',
#   7],
#  [datetime.datetime(2022, 5, 9, 21, 37, 10, tzinfo=datetime.timezone.utc),
#   1523779132999585794,
#   'First migrants slated for deportation to Rwanda will be told this week https://t.co/YdEIzCMZox',
#   'DailyMailUK',
#   35],
#  [datetime.datetime(2022, 5, 9, 19, 23, 5, tzinfo=datetime.timezone.utc),
#   1523745391317028867,
#   "Man 'in handcuffs' among group of migrants landing in Dover https://t.co/dwuN9lcGoe",
#   'DailyMailUK',
#   7],
#  [datetime.datetime(2022, 5, 9, 17, 39, 3, tzinfo=datetime.timezone.utc),
#   1523719208110075905,
#   'How a Rwandan refugee became the 14th Time Lord https://t.co/9y7COYgw73',
#   'DailyMailUK',
#   6],
#  [datetime.datetime(2022, 5, 9, 13, 40, 7, tzinfo=datetime.timezone.utc),
#   1523659077808701446,
#   "'My hometown was turned into hell': Ukrainian refugee tells how vacuum bomb destroyed school https://t.co/qI3SHDTjCr",
#   'DailyMailUK',
#   3],
#  [datetime.datetime(2022, 5, 9, 13, 25, 4, tzinfo=datetime.timezone.utc),
#   1523655293304987648,
#   "'My hometown was turned into HELL': Ukrainian refugee recalls deadly vacuum bomb that destroyed school near home https://t.co/XITqoXvW1s",
#   'MailOnline',
#   5],
#  [datetime.datetime(2022, 5, 9, 10, 50, 10, tzinfo=datetime.timezone.utc),
#   1523616308448968704,
#   'Priti Patel will tell migrants THIS WEEK they will be shipped to Rwanda https://t.co/QFWTq29fcK',
#   'DailyMailUK',
#   33],
#  [datetime.datetime(2022, 5, 9, 9, 50, 2, tzinfo=datetime.timezone.utc),
#   1523601177425940480,
#   'Priti Patel will tell migrants THIS WEEK that they will be shipped to Rwanda - in bid to avoid delays caused by legal challenges https://t.co/KE63sX0ol4',
#   'MailOnline',
#   23],
#  [datetime.datetime(2022, 5, 9, 9, 10, 2, tzinfo=datetime.timezone.utc),
#   1523591110798548992,
#   'Victorious Sinn Fein raises pressure for a border poll https://t.co/BTVoqKrbBx',
#   'DailyMailUK',
#   2],
#  [datetime.datetime(2022, 5, 8, 14, 30, 8, tzinfo=datetime.timezone.utc),
#   1523309277905309696,
#   "MoD's 8,000 empty houses should house Ukrainian refugees, Lib Dems say https://t.co/Imu4kUKKXF",
#   'DailyMailUK',
#   17],
#  [datetime.datetime(2022, 5, 8, 14, 15, 7, tzinfo=datetime.timezone.utc),
#   1523305499412041729,
#   "Jill Biden met with Ukrainian refugees because she was so 'inspired' https://t.co/cI1I5VoJGw",
#   'MailOnline',
#   35],
#  [datetime.datetime(2022, 5, 8, 9, 31, 16, tzinfo=datetime.timezone.utc),
#   1523234067021369344,
#   'Plan to send failed asylum seekers to Rwanda will get under way next week https://t.co/9r1SkmjpZr',
#   'TheSun',
#   25],
#  [datetime.datetime(2022, 5, 7, 21, 0, 5, tzinfo=datetime.timezone.utc),
#   1523045025340624897,
# ...
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 3, 14, 14, 40, 8, tzinfo=datetime.timezone.utc),
#   1503380461996978192,
#   'Grant Shapps becomes first minister to offer up his home to a Ukrainian refugee as Boris Johnson refuses to open up No10 https://t.co/vUfzrY6SFm',
#   'DailyMailUK',
#   29],
#  [datetime.datetime(2022, 3, 14, 14, 40, tzinfo=datetime.timezone.utc),
#   1503380428626964488,
#   'Sweet moment volunteer brings a smile to a child waiting at Polish border crossing https://t.co/QKEp2s2VOa',
#   'TheSun',
#   83],
#  [datetime.datetime(2022, 3, 14, 14, 25, 3, tzinfo=datetime.timezone.utc),
#   1503376667376603139,
#   "Putin deliberately targeted Ukraine's 'foreign legion' with strike 12 miles from NATO border https://t.co/ojHpW0J6cw",
#   'MailOnline',
#   24],
#  [datetime.datetime(2022, 3, 14, 14, 5, 5, tzinfo=datetime.timezone.utc),
#   1503371643674112001,
#   'Incredible moment whole school in Italy greets nervous Ukrainian refugee children https://t.co/SNNsm0yHJl',
#   'MailOnline',
#   48],
#  [datetime.datetime(2022, 3, 14, 13, 45, 2, tzinfo=datetime.timezone.utc),
#   1503366598471602176,
#   "'We have brothers and sisters who are suffering': Benedict Cumberbatch says he hopes to take in Ukrainian refugees https://t.co/6qapTL2i3F",
#   'MailOnline',
#   31],
#  [datetime.datetime(2022, 3, 14, 13, 25, 6, tzinfo=datetime.timezone.utc),
#   1503361581471649793,
#   "Riot police storm Russian oligarch's £50million 'crash-pad' after it was invaded by activists vowing to house Ukrainian refugees there https://t.co/oEOO7XkZUI https://t.co/uqJ6dvuxsb",
#   'MailOnline',
#   29],
#  [datetime.datetime(2022, 3, 14, 13, 0, 2, tzinfo=datetime.timezone.utc),
#   1503355273150357505,
#   "'Ok if you are filthy rich!' Gove's £350 refugee offer to Britons slapped down – new poll\nhttps://t.co/iKs0Bng014 https://t.co/JIuZtLT6BO",
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 3, 14, 12, 40, 9, tzinfo=datetime.timezone.utc),
#   1503350267286364169,
#   "Homes Under The Hammer's Martin Roberts arrives in Poland after 26 hours drive to take supplies to Ukrainian border https://t.co/7CU3vOhT7h",
#   'DailyMailUK',
#   20],
#  [datetime.datetime(2022, 3, 14, 12, 35, 4, tzinfo=datetime.timezone.utc),
#   1503348986991845376,
#   "'This property belongs to Ukrainian refugees': Activists occupy Russian oligarch's £50million 'crash-pad' and vow to stay until Putin stops war https://t.co/DbgkhvQs35",
#   'MailOnline',
#   45],
#  [datetime.datetime(2022, 3, 14, 12, 6, tzinfo=datetime.timezone.utc),
#   1503341673144750084,
#   "Martin Roberts warned it's 'too dangerous' to enter Ukraine after 26-hour drive to border\nhttps://t.co/pxNhnGXQnu",
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 3, 14, 11, 45, 9, tzinfo=datetime.timezone.utc),
#   1503336425680519182,
#   'British families can only take in Ukrainian refugees if they already know their NAMES https://t.co/fzi8Ev47rP',
#   'DailyMailUK',
#   6],
#  [datetime.datetime(2022, 3, 14, 11, 37, tzinfo=datetime.timezone.utc),
#   1503334375181717510,
#   'Benedict Cumberbatch calls on Brits to ‘do more’ as he vows to take in Ukrainian refugees https://t.co/rs450Q5kcA',
#   'Daily_Express',
#   0],
#  [datetime.datetime(2022, 3, 14, 11, 35, 5, tzinfo=datetime.timezone.utc),
#   1503333892685766664,
#   "Putin deliberately targeted Ukraine's 'foreign legion' with strike 12 miles from NATO border https://t.co/4ORx7w9ypP",
#   'MailOnline',
#   53],
#  [datetime.datetime(2022, 3, 14, 11, 30, 46, tzinfo=datetime.timezone.utc),
#   1503332806289764357,
#   'Tens of thousands of Brits expected to put up Ukrainian refugees fleeing war https://t.co/Be3zupVrk5',
#   'TheSun',
#   9],
#  [datetime.datetime(2022, 3, 14, 11, 25, 6, tzinfo=datetime.timezone.utc),
#   1503331382084386819,
#   'British families can only take in Ukrainian refugees if they already know their NAMES https://t.co/bN0fDxlsHV',
#   'MailOnline',
#   12],
#  [datetime.datetime(2022, 3, 14, 11, 25, tzinfo=datetime.timezone.utc),
#   1503331355165433857,
#   "'Ok if you are filthy rich!' Gove's £350 refugee offer to Britons slapped down – new poll\nhttps://t.co/iKs0Bng014 https://t.co/mWMIkAbngm",
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 3, 14, 11, 5, 3, tzinfo=datetime.timezone.utc),
#   1503326334902231041,
#   "UK TV presenter reveals he's arrived in Poland after driving 26 hours on 'mercy dash' to take supplies to Ukrainian border https://t.co/HfnYj4P5Zv",
#   'MailOnline',
#   62],
#  [datetime.datetime(2022, 3, 14, 11, 0, 1, tzinfo=datetime.timezone.utc),
#   1503325068515962881,
#   'Sweet moment volunteer brings a smile to a child waiting at Polish border crossing https://t.co/GuilsvIqU2',
#   'TheSun',
#   120],
#  [datetime.datetime(2022, 3, 14, 10, 26, 39, tzinfo=datetime.timezone.utc),
#   1503316671980883972,
#   'Diabetes: Lancet warns of ‘serious long-term health consequences’ for diabetic refugees\nhttps://t.co/9JoT395UXe',
#   'Daily_Express',
#   1],
#  [datetime.datetime(2022, 3, 14, 10, 16, 41, tzinfo=datetime.timezone.utc),
#   1503314162851713028,
#   'The anti-fascists say they intend to use the mansion “as a refugee support, for people of Ukraine"\n\nhttps://t.co/0lp0vEjjUS',
#   'Daily_Express',
#   6],
#  [datetime.datetime(2022, 3, 14, 10, 5, tzinfo=datetime.timezone.utc),
#   1503311224460750848,
#   "'Ok if you are filthy rich!' Gove's £350 refugee offer to Britons slapped down – new poll\nhttps://t.co/iKs0Bng014 https://t.co/zmUlYfCXqx",
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 3, 14, 9, 37, tzinfo=datetime.timezone.utc),
#   1503304175936946177,
#   'Benedict Cumberbatch calls on Brits to ‘do more’ as he vows to take in Ukrainian refugees https://t.co/rs450QmV48',
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 3, 14, 9, 30, 11, tzinfo=datetime.timezone.utc),
#   1503302460584120326,
#   'M&amp;S, Asos and Lush are keen to hire Ukrainian refugees https://t.co/yfDmvITEhm',
#   'DailyMailUK',
#   15],
#  [datetime.datetime(2022, 3, 14, 9, 0, 9, tzinfo=datetime.timezone.utc),
#   1503294904256147460,
#   'Benedict Cumberbatch says he hopes to take in Ukrainian refugees https://t.co/nUSgk4bbus',
#   'DailyMailUK',
#   16],
#  [datetime.datetime(2022, 3, 14, 8, 20, 39, tzinfo=datetime.timezone.utc),
#   1503284963487240193,
#   "Moscow claims there has been 'substantial progress' in peace talks despite attack just 12 miles from NATO border https://t.co/LIofer3eUc https://t.co/cjDyhBSF1H",
#   'MailOnline',
#   23],
#  [datetime.datetime(2022, 3, 14, 7, 54, 15, tzinfo=datetime.timezone.utc),
#   1503278318929465347,
#   "'Could have happened quicker!' Sajid Javid grilled over UK aid for Ukraine refugees\nhttps://t.co/gB8ec2KZVu",
#   'Daily_Express',
#   4],
#  [datetime.datetime(2022, 3, 14, 6, 12, tzinfo=datetime.timezone.utc),
#   1503252585993617411,
#   'Sturgeon will take in Ukrainian refugees ‘if needed’ after bashing Government scheme \n\nhttps://t.co/wuh0N0g7BT https://t.co/gnML8vAhq0',
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 3, 14, 6, 3, 57, tzinfo=datetime.timezone.utc),
#   1503250560111333376,
#   'Brits will be offered £350 a month to take a Ukrainian refugee into their home https://t.co/PmQllzIEon',
#   'DailyMailUK',
#   7],
#  [datetime.datetime(2022, 3, 14, 5, 20, 9, tzinfo=datetime.timezone.utc),
#   1503239537899810818,
#   "Putin's bombs hit Orthodox Christian monastery sheltering 1,000 refugees https://t.co/5RanYOJM3O",
#   'MailOnline',
#   28],
#  [datetime.datetime(2022, 3, 14, 5, 8, 35, tzinfo=datetime.timezone.utc),
#   1503236628919291909,
#   'Michael Gove hails Brits offering to host Ukraine refugees https://t.co/KUF6Ng8mGr',
#   'DailyMailUK',
#   11],
#  [datetime.datetime(2022, 3, 13, 23, 37, tzinfo=datetime.timezone.utc),
#   1503153180959510532,
#   'Benedict Cumberbatch calls on Brits to ‘do more’ as he vows to take in Ukrainian refugees https://t.co/rs450Q5kcA',
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 3, 13, 22, 37, 12, tzinfo=datetime.timezone.utc),
#   1503138132111376393,
#   "On tomorrow's front page: Russia airstrike hits just 11 miles from Nato border killing 35 at base\n\nhttps://t.co/4xPjLsxnso https://t.co/uFyuzMT6Gk",
#   'TheSun',
#   16],
#  [datetime.datetime(2022, 3, 13, 21, 45, 5, tzinfo=datetime.timezone.utc),
#   1503125017151905794,
#   'Michael Gove defies Cabinet backlash and calls for oligarch mansions to house Ukrainian refugees https://t.co/6oq7wAela5',
#   'DailyMailUK',
#   17],
#  [datetime.datetime(2022, 3, 13, 21, 36, tzinfo=datetime.timezone.utc),
#   1503122730257772544,
#   'Benedict Cumberbatch calls on Brits to ‘do more’ as he vows to take in Ukrainian refugees https://t.co/rs450QmV48',
#   'Daily_Express',
#   7],
#  [datetime.datetime(2022, 3, 13, 20, 45, 8, tzinfo=datetime.timezone.utc),
#   1503109929128841220,
#   'Russian Orthodox church in Oxford is ransacked by burglars who stole fundraising cash for Ukrainian refugees https://t.co/Fry4kpTKxK',
#   'DailyMailUK',
#   6],
#  [datetime.datetime(2022, 3, 13, 20, 20, 4, tzinfo=datetime.timezone.utc),
#   1503103622485356549,
#   'Woman is killed and dozens are injured after bus carrying 50 Ukrainian refugees overturns in Italy https://t.co/gMxAIuMbt5',
#   'MailOnline',
#   34],
#  [datetime.datetime(2022, 3, 13, 19, 30, 59, tzinfo=datetime.timezone.utc),
#   1503091271660937228,
#   "Roman Abramovich’s £150m London mansion 'could be used to house Ukraine refugees' https://t.co/zJ5uXrPR6Z",
#   'TheSun',
#   36],
#  [datetime.datetime(2022, 3, 13, 19, 20, 6, tzinfo=datetime.timezone.utc),
#   1503088532641955840,
#   'Benedict Cumberbatch says he hopes to take in Ukrainian refugees https://t.co/of7vr7plQj',
#   'DailyMailUK',
#   58],
#  [datetime.datetime(2022, 3, 13, 17, 45, 44, tzinfo=datetime.timezone.utc),
#   1503064782563430407,
#   'Brits to be given £350-a-month to open homes to Ukraine refugees\nhttps://t.co/VQhJaX31kJ',
#   'TheSun',
#   16],
#  [datetime.datetime(2022, 3, 13, 17, 30, 6, tzinfo=datetime.timezone.utc),
#   1503060847781978120,
#   'Michael Gove defies Cabinet backlash and calls for oligarch mansions to house Ukrainian refugees https://t.co/JWRiZLYKsx',
#   'DailyMailUK',
#   22],
#  [datetime.datetime(2022, 3, 13, 15, 1, 4, tzinfo=datetime.timezone.utc),
#   1503023344559476740,
#   "Roman Abramovich’s £150m London mansion 'could be used to house Ukraine refugees' https://t.co/Bllkjwvchm",
#   'TheSun',
#   56],
#  [datetime.datetime(2022, 3, 13, 14, 40, 5, tzinfo=datetime.timezone.utc),
#   1503018062240440323,
#   'Woman is killed and dozens are injured after bus carrying 50 Ukrainian refugees overturns in Italy https://t.co/YGSuxmh6IK',
#   'MailOnline',
#   13],
#  [datetime.datetime(2022, 3, 13, 14, 37, 50, tzinfo=datetime.timezone.utc),
#   1503017497968230400,
#   "Putin's bombs hit Orthodox Christian monastery sheltering 1,000 refugees https://t.co/6YEFhbR71m",
#   'MailOnline',
#   36],
#  [datetime.datetime(2022, 3, 13, 14, 20, 5, tzinfo=datetime.timezone.utc),
#   1503013029146996737,
#   '30 Russian missiles hit military base and kill 35 close to Nato border https://t.co/tcuN3EH5g5',
#   'MailOnline',
#   26],
#  [datetime.datetime(2022, 3, 13, 12, 16, 2, tzinfo=datetime.timezone.utc),
#   1502981809600090117,
#   'Brits to be paid over £2,000 to open homes to refugees fleeing Ukraine war\nhttps://t.co/kMYeYT2npW',
#   'TheSun',
#   13],
#  [datetime.datetime(2022, 3, 13, 12, 0, 27, tzinfo=datetime.timezone.utc),
#   1502977888982900746,
#   'Russia airstrike hits just 12 miles from Nato border killing 35 at base where foreign instructors are helping Ukrainians https://t.co/InYfMua0r9',
#   'TheSun',
#   20],
#  [datetime.datetime(2022, 3, 13, 11, 53, 54, tzinfo=datetime.timezone.utc),
#   1502976242450149376,
#   'Ukrainian refugee killed when bus she was in veered off motorway in Italy https://t.co/zPkpCFrAJ2 https://t.co/h61hdR9TLg',
#   'TheSun',
#   12],
#  [datetime.datetime(2022, 3, 13, 11, 45, 8, tzinfo=datetime.timezone.utc),
#   1502974035092721668,
#   'Woman is killed and dozens are injured after bus carrying 50 Ukrainian refugees overturns in Italy https://t.co/T1FLufA67z',
#   'MailOnline',
#   28],
#  [datetime.datetime(2022, 3, 13, 11, 30, 3, tzinfo=datetime.timezone.utc),
#   1502970238618456066,
#   '30 Russian missiles hit military base and kill 35 close to Nato border https://t.co/GXEzWw23LB',
#   'MailOnline',
#   53],
#  [datetime.datetime(2022, 3, 13, 10, 30, 2, tzinfo=datetime.timezone.utc),
#   1502955137173803011,
#   "Putin's forces strike military base just 12 MILES from Nato border https://t.co/j23Jropatq",
#   'MailOnline',
#   32],
#  [datetime.datetime(2022, 3, 13, 9, 30, 5, tzinfo=datetime.timezone.utc),
#   1502940046722277379,
#   'Michael Gove hails Brits offering to host Ukraine refugees https://t.co/7cb7PMifpD',
#   'DailyMailUK',
#   14],
#  [datetime.datetime(2022, 3, 13, 9, 14, 7, tzinfo=datetime.timezone.utc),
#   1502936031569620996,
#   "Putin's forces strike military base just 20 miles from NATO border\n \nUKRAINE LATEST: https://t.co/CskRXw7Wzt https://t.co/30NbjIc777",
#   'MailOnline',
#   34],
#  [datetime.datetime(2022, 3, 13, 8, 53, 25, tzinfo=datetime.timezone.utc),
#   1502930822281707527,
#   'Brits will be offered £350 a month to take a Ukrainian refugee into their home https://t.co/RfL0lVD0o5',
#   'DailyMailUK',
#   56],
#  [datetime.datetime(2022, 3, 13, 8, 46, 6, tzinfo=datetime.timezone.utc),
#   1502928980671971334,
#   "Roman Abramovich’s £150m London mansion 'could be used to house Ukraine refugees' https://t.co/m2TnjhdXX9",
#   'TheSun',
#   63],
#  [datetime.datetime(2022, 3, 13, 8, 0, 48, tzinfo=datetime.timezone.utc),
#   1502917577563119617,
#   'Brits to be paid over £2,000 to open homes to refugees fleeing Ukraine war\nhttps://t.co/z86JX8Ez5W',
#   'TheSun',
#   10],
#  [datetime.datetime(2022, 3, 12, 23, 30, tzinfo=datetime.timezone.utc),
#   1502789032492736514,
#   "#Strictly star in tears after family 'turned back' at #Ukraine️ border as Judge Rinder helps\nhttps://t.co/JfN7l9VJmd https://t.co/9QjKMdfIbW",
#   'Daily_Express',
#   0],
#  [datetime.datetime(2022, 3, 12, 22, 31, 8, tzinfo=datetime.timezone.utc),
#   1502774216336289805,
#   "Emmanuel Macron condemns the UK for not living up to 'grand statements' it made on helping Ukrainian refugees https://t.co/AxznKwN5yH",
#   'MailOnline',
#   101],
#  [datetime.datetime(2022, 3, 12, 22, 6, 34, tzinfo=datetime.timezone.utc),
#   1502768036545273858,
#   'Seize Russian oligarch mansions to house Ukrainian refugees, Michael Gove demands https://t.co/DRvvv0spgi',
#   'DailyMailUK',
#   196],
#  [datetime.datetime(2022, 3, 12, 21, 30, tzinfo=datetime.timezone.utc),
#   1502758833000644608,
#   "#Strictly star in tears after family 'turned back' at #Ukraine️ border as Judge Rinder helps\nhttps://t.co/JfN7l9VJmd https://t.co/I9O6ztYUki",
#   'Daily_Express',
#   2],
#  [datetime.datetime(2022, 3, 12, 20, 45, 8, tzinfo=datetime.timezone.utc),
#   1502747544614580226,
#   "Black refugee from Ukraine says French 'have split people of colour from white ones' https://t.co/uvwzrt0DXa",
#   'DailyMailUK',
#   16],
#  [datetime.datetime(2022, 3, 12, 20, 30, tzinfo=datetime.timezone.utc),
#   1502743734122909708,
#   "#Strictly star in tears after family 'turned back' at #Ukraine️ border as Judge Rinder helps\nhttps://t.co/JfN7l9E8uF https://t.co/VMPLaFSgRS",
#   'Daily_Express',
#   10],
#  [datetime.datetime(2022, 3, 12, 19, 45, 5, tzinfo=datetime.timezone.utc),
#   1502732428972015616,
#   "TV stars demand government 'let Ukrainian refugees in now - with open arms' https://t.co/VNscf2VKMT",
#   'DailyMailUK',
#   27],
#  [datetime.datetime(2022, 3, 12, 19, 32, 36, tzinfo=datetime.timezone.utc),
#   1502729288491094020,
#   "Emmanuel Macron condemns the UK for not living up to 'grand statements' it made on helping Ukrainian refugees https://t.co/vHwrqyBUQF",
#   'MailOnline',
#   68],
#  [datetime.datetime(2022, 3, 12, 17, 30, 13, tzinfo=datetime.timezone.utc),
#   1502698488366309379,
#   "Black refugee from Ukraine says French 'have split people of colour from white ones' https://t.co/OuVV6RvttU",
#   'MailOnline',
#   15],
#  [datetime.datetime(2022, 3, 12, 17, 30, tzinfo=datetime.timezone.utc),
#   1502698437187416065,
#   "#Strictly star in tears after family 'turned back' at #Ukraine️ border as Judge Rinder helps\nhttps://t.co/JfN7l9E8uF https://t.co/0W5J2sqvbP",
#   'Daily_Express',
#   4],
#  ...]

# %%
len(tweets_list)
# Out:
# 2001

# %%
# Creating a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username','Like Count'])
tweets_df.head(5)
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-06-07 02:12:00+00:00  1533995157858795525
# 1 2022-06-06 11:40:05+00:00  1533775732345823232
# 2 2022-06-05 03:29:56+00:00  1533289994584002561
# 3 2022-06-04 00:40:42+00:00  1532885015918411777
# 4 2022-06-03 23:30:07+00:00  1532867253988884485
#
#                                                 Text       Username  \
# 0  Biden blasted for ‘monumental disaster’ as 11,...  Daily_Express
# 1  More than 45,000 Americans apply to sponsor Uk...     MailOnline
# 2  Anger as hundreds of refugee children from Ukr...     MailOnline
# 3  More than 10,000 migrants have already crossed...     MailOnline
# 4  This week marked one hundred days since Russia...     MailOnline
#
#    Like Count
# 0           3
# 1          17
# 2          16
# 3          17
# 4          16

# %%
tweets_df.to_csv('2k_general.csv')
