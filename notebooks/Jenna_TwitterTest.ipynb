# %%
import requests
import os
import json

# %%
# set bearer token as environment variable in terminal
bearer_token = ""

# %%
search_url = "https://api.twitter.com/2/tweets/search/recent"

# %%
query_params2 = {'query': '(from:TheSun OR from:DailyMailUK OR from:MailOnline OR from:Daily_Express) -is:retweet (migrant OR migrants OR migration OR foreigner OR foreigners OR terrorism OR terrorist OR terrorists OR immigration OR immigrants OR immigrant OR muslim OR asian OR asylum OR refugee OR refugees OR visa OR visas)',
                'max_results': 50, 'expansions':'author_id', 'tweet.fields': 'author_id,created_at,public_metrics'}

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"

    return r

# %%
def connect_to_endpoint(url, params):
    response = requests.get(url=url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
connect_to_endpoint(search_url,query_params2)
# Out:
# 200
# {'data': [{'id': '1533775732345823232',
#    'author_id': '15438913',
#    'text': 'More than 45,000 Americans apply to sponsor Ukrainian refugees in just a month https://t.co/tFO8AFjXaE',
#    'public_metrics': {'retweet_count': 3,
#     'reply_count': 7,
#     'like_count': 10,
#     'quote_count': 1},
#    'created_at': '2022-06-06T11:40:05.000Z'},
#   {'id': '1533526293937065984',
#    'author_id': '34655603',
#    'text': "11 of UK's most dangerous terrorists will be freed this year\nhttps://t.co/uqBHUmEyrT",
#    'public_metrics': {'retweet_count': 9,
#     'reply_count': 13,
#     'like_count': 11,
#     'quote_count': 4},
#    'created_at': '2022-06-05T19:08:54.000Z'},
#   {'id': '1533444994371051520',
#    'author_id': '34655603',
#    'text': "11 of UK's most dangerous terrorists will be freed this year\nhttps://t.co/a5m9gFilTM",
#    'public_metrics': {'retweet_count': 6,
#     'reply_count': 5,
#     'like_count': 14,
#     'quote_count': 1},
# ...

# %% [markdown]
# ### Notes

# %% [markdown]
# Query builder:
# https://developer.twitter.com/apitools/api?endpoint=%2F2%2Ftweets%2Fsearch%2Fall&method=get

# %%
#r.headers["User-Agent"] = "v2RecentSearchPython"# v2UserTweetsPython



# by user
#def create_url():
#     user_id = "34655603"
#     url = "https://api.twitter.com/2/users/{}/tweets".format(user_id)
#     return url

#url = create_url()

# %%
# query_params2 = {'query': '(from:TheSun OR from:DailyMailUK OR from:MailOnline OR from:Daily_Express) -is:retweet (immigration OR crossing OR visa OR visas OR refugee OR migrants OR terrorist OR terrorists OR refugees OR migrant OR homeoffice OR muslim OR asian OR foreigner)',
                'max_results': 100}

# %% [markdown]
# Migrant groups in the UK:
# - India
# - Pakistan
# - Poland
# - Romania
# - Bangladesh
# - Afghan
# - Syria
# - Iran
# - Iraq
# - Albania
# - Chinese - foot and mouth disease, covid
#
# Religion:
# - Jewish - Israeli Palestinian war, antisemitism
# - Muslim, muslims - bombings
#
# General groups of migrants
# - migrant, migrants, migration
# - foreign, foreigner, foreigners
# - terrorism, terrorist, terrorists
# - immigration, immigrants, immigrant
# - asylum
# - refugee, refugees
#
#
# General words:
# - deport, deportation, deported
# - visa, visas
# - border, borders
# - racism, racist
# - illegal
# - brexit
# - population growth
# - floodgate, floodgates
#
# Tweet annotations / places
# - Home Office

# %%
migrant OR migrants OR migration OR foreign OR foreigner OR foreigners OR 
terrorism OR terrorist OR terrorists OR immigration OR immigrants OR immigrant OR
muslim OR asian OR 
asylum OR 
refugee OR refugees OR
visa OR visas



immigration OR crossing OR visa OR visas OR refugee OR migrants OR terrorist OR terrorists 
OR refugees OR migrant OR homeoffice OR muslim OR asian OR foreigner
