# %%
import pandas as pd

# %%
df = pd.read_csv('../data/2k_general.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0                   Datetime      Tweet Id  \
# 0            0  2022-06-07 02:12:00+00:00  1.534000e+18
# 1            1  2022-06-06 11:40:05+00:00  1.533780e+18
# 2            2  2022-06-05 03:29:56+00:00  1.533290e+18
# 3            3  2022-06-04 00:40:42+00:00  1.532890e+18
# 4            4  2022-06-03 23:30:07+00:00  1.532870e+18
# 5            5  2022-06-03 10:43:47+00:00  1.532670e+18
# 6            6  2022-06-03 02:26:00+00:00  1.532550e+18
# 7            7  2022-06-02 19:52:05+00:00  1.532450e+18
# 8            8  2022-06-02 16:01:34+00:00  1.532390e+18
# 9            9  2022-06-02 12:58:04+00:00  1.532350e+18
# 10          10  2022-06-02 03:58:54+00:00  1.532210e+18
# 11          11  2022-06-02 00:30:03+00:00  1.532160e+18
# 12          12  2022-06-01 15:10:05+00:00  1.532020e+18
# 13          13  2022-06-01 14:10:06+00:00  1.532000e+18
# 14          14  2022-06-01 12:20:09+00:00  1.531970e+18
# 15          15  2022-06-01 00:16:00+00:00  1.531790e+18
# ...

# %%
df.Text[50]
# Out:
# 'Boris Becker moved to prison for foreign criminals facing deportation https://t.co/B46HhlEjsW'

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Datetime       object
# Tweet Id      float64
# Text           object
# Username       object
# Like Count      int64
# dtype: object

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import string
string.punctuation 
print (string.punctuation) 
stop_words = stopwords.words('english')

def preprocessing(df):
    special_characters = df.str.replace('[^\w\s]','')
    URL = special_characters.replace(r'https.*$', "", regex = True)                               
    HTML = [BeautifulSoup(text).get_text() for text in URL]   
    stopwords = [word for word in HTML if word not in (stop_words)]
                                             
    return " ".join(element for element in stopwords)
#     return special_characters
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/johnlatham/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(preprocessing(df['Text']))
# Out:
# /var/folders/g1/c5jcf31s45sdm99hhxcwl2br0000gn/T/ipykernel_63923/2791523028.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   special_characters = df.str.replace('[^\w\s]','')
# Biden blasted for monumental disaster as 11000 migrants head to the USMexico border
#
#  More than 45000 Americans apply to sponsor Ukrainian refugees in just a month  Anger as hundreds of refugee children from Ukraine are left stranded abroad following Home Office rule change  More than 10000 migrants have already crossed the Channel this year despite the threat they could be deported to Rwanda  This week marked one hundred days since Russian tanks rolled across the border and into neighbouring Ukraine  It cant go on like this Rwanda policy not working as almost 10000 migrants reach UK
#  Biden close to finalising deal to send refugees to Spain amid staggering migrant crisis
#
# ...

# %%
# df['new_column'] = df.Text.apply(preprocessing)

df['text_punct'] = df['Text'].str.replace('[^\w\s]','')
# Out:
# /var/folders/g1/c5jcf31s45sdm99hhxcwl2br0000gn/T/ipykernel_63923/3561732769.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['text_punct'] = df['Text'].str.replace('[^\w\s]','')

# %%
df['text_punct']
# Out:
# 0       Biden blasted for monumental disaster as 11000...
# 1       More than 45000 Americans apply to sponsor Ukr...
# 2       Anger as hundreds of refugee children from Ukr...
# 3       More than 10000 migrants have already crossed ...
# 4       This week marked one hundred days since Russia...
#                               ...
# 1996    More migrants reached the UK on Sunday alone t...
# 1997    More than 1000 migrants tried to cross the Cha...
# 1998    More migrants reached the UK on Sunday alone t...
# 1999    More than 1000 migrants tried to cross the Cha...
# 2000    RNLI help another 45 migrants ashore on misty ...
# Name: text_punct, Length: 2001, dtype: object

# %%
example.translate(str.maketrans("", "", string.punctuation))

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')
df['stopwords'] = df['Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
df['characters']  = df['Text'].replace(r'[[]!"#$%\'()\*+,-./:;<=>?^_`{|}]+',"", regex = True)

# %%
import re
def cleaning_PicURL (text):
    text = re.sub(r'pic.twitter.com/[\w]*',"", text)
    return text

# %%
df['imgs'] = df['Text'].apply(lambda x: cleaning_PicURL(x))

# %%
from bs4 import BeautifulSoup
df['HTML_tags'] = [BeautifulSoup(text).get_text() for text in df['Text'] ]
